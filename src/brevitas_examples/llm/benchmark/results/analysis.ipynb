# %%
import pandas as pd  
  
# Load the CSV file into a DataFrame  
df = pd.read_csv('/home/pmonteag/work/clones/brevitas/src/brevitas_examples/llm/benchmark/results/results.csv')  
#condition = )  
df = df[(df['model'] == 'meta-llama/Llama-3.2-1B') & (df['nsamples'] == 128) & (df['add_bos_token'] == False)]
# Select a subset of columns  
selected_columns = ['model', 'dataset', 'quant_ppl', 'leaderboard:arc:challenge:0_acc', 'lighteval:arc:easy:0_acc', 'leaderboard:hellaswag:0_acc', 'leaderboard:winogrande:0_acc', 'lighteval:piqa:0_acc']  # Specify the column names you are interested in  
df = df[selected_columns]  
  
# Apply conditions to filter the rows  
# Example: Filter rows where 'Column1' is greater than 10 and 'Column3' is equal to 'some_value'  

  
# Display the filtered DataFrame  
print(df)

df.to_csv('results_1b.csv')
# Out:
#                       model        dataset  quant_ppl  \
# 1   meta-llama/Llama-3.2-1B  wikitext2_clm    13.5625
# 7   meta-llama/Llama-3.2-1B         c4_clm    13.8125
# 13  meta-llama/Llama-3.2-1B       pile_clm    14.2500
#
#     leaderboard:arc:challenge:0_acc  lighteval:arc:easy:0_acc  \
# 1                          0.269625                  0.559343
# 7                          0.280717                  0.557239
# 13                         0.259386                  0.560185
#
#     leaderboard:hellaswag:0_acc  leaderboard:winogrande:0_acc  \
# 1                      0.410177                      0.537490
# 7                      0.412468                      0.554065
# 13                     0.400916                      0.524073
#
#     lighteval:piqa:0_acc
# 1               0.675734
# 7               0.667573
# 13              0.667573

# %%
import pandas as pd  
  
# Load the CSV file into a DataFrame  
df = pd.read_csv('/home/pmonteag/work/clones/brevitas/src/brevitas_examples/llm/benchmark/results/results.csv')  
#condition = )  
df = df[(df['model'] == 'meta-llama/Llama-3.2-3B') & (df['nsamples'] == 128) & (df['add_bos_token'] == False)]
# Select a subset of columns  
selected_columns = ['model', 'dataset', 'quant_ppl', 'leaderboard:arc:challenge:0_acc', 'lighteval:arc:easy:0_acc', 'leaderboard:hellaswag:0_acc', 'leaderboard:winogrande:0_acc', 'lighteval:piqa:0_acc']  # Specify the column names you are interested in  
df = df[selected_columns]  
  
# Apply conditions to filter the rows  
# Example: Filter rows where 'Column1' is greater than 10 and 'Column3' is equal to 'some_value'  

  
# Display the filtered DataFrame  
print(df)  


df.to_csv('results_3b.csv')
# Out:
#                       model        dataset  quant_ppl  \
# 4   meta-llama/Llama-3.2-3B  wikitext2_clm     9.3125
# 10  meta-llama/Llama-3.2-3B         c4_clm     9.5000
# 16  meta-llama/Llama-3.2-3B       pile_clm     9.5000
#
#     leaderboard:arc:challenge:0_acc  lighteval:arc:easy:0_acc  \
# 4                          0.339590                  0.662879
# 10                         0.357509                  0.682660
# 16                         0.339590                  0.672559
#
#     leaderboard:hellaswag:0_acc  leaderboard:winogrande:0_acc  \
# 4                      0.491038                      0.591949
# 10                     0.497510                      0.591160
# 16                     0.490540                      0.585635
#
#     lighteval:piqa:0_acc
# 4               0.716540
# 10              0.732318
# 16              0.717628
